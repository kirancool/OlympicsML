# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
athletes=pd.read_csv('datasets/Olympic/athlete_events.csv')
region=pd.read_csv('datasets/Olympic/noc_regions.csv')

# %%
athletes
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
region
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
athletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
athletes.isna().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
region.isna().sum()
# Out:
# NOC         0
# region      3
# notes     209
# dtype: int64

# %%
df=athletes.merge(region,how='left',on='NOC')

# %%
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df.isna().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# region       370
# notes     266077
# dtype: int64

# %%
df['notes']=df['notes'].fillna(0)

# %%
df['Medal'] = df['Medal'].fillna(0)

# %%
df[(df['Team']=='India') & (df['Name']=='Milkha Singh')]
# Out:
#             ID          Name Sex   Age  Height  Weight   Team  NOC  \
# 221116  111108  Milkha Singh   M  21.0   172.0    66.0  India  IND
# 221117  111108  Milkha Singh   M  21.0   172.0    66.0  India  IND
# 221118  111108  Milkha Singh   M  24.0   172.0    66.0  India  IND
# 221119  111108  Milkha Singh   M  28.0   172.0    66.0  India  IND
#
#               Games  Year  Season       City      Sport  \
# 221116  1956 Summer  1956  Summer  Melbourne  Athletics
# 221117  1956 Summer  1956  Summer  Melbourne  Athletics
# 221118  1960 Summer  1960  Summer       Roma  Athletics
# 221119  1964 Summer  1964  Summer      Tokyo  Athletics
#
#                                        Event Medal region notes
# 221116            Athletics Men's 200 metres     0  India     0
# 221117            Athletics Men's 400 metres     0  India     0
# 221118            Athletics Men's 400 metres     0  India     0
# 221119  Athletics Men's 4 x 400 metres Relay     0  India     0

# %%
df.groupby('notes').notes.count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='notes'>

# %%
fig = plt.figure(figsize=(30,10))
sns.countplot(df['notes'],data=df)
plt.show()
# Out:
# D:\Juypitor\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
top_10_country=df['Team'].value_counts().sort_values(ascending=False).head(10)
top_10_country
# Out:
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
# Canada            9279
# Japan             8289
# Sweden            8052
# Australia         7513
# Hungary           6547
# Name: Team, dtype: int64

# %%
fig = plt.figure(figsize=(10,20))
#sns.barplot(top_10_country,data=df['Team'])
sns.barplot(x=top_10_country.index,y =top_10_country)
plt.title("Top 10 country")
plt.xlabel('country')
plt.ylabel('Number of Players')
plt.show()

# %%
#Age distribution of player in histogram

plt.figure(figsize=(12,10))
plt.hist(df['Age'],bins=np.arange(10,60),color='Orange',edgecolor='white')
plt.title("Age Distribution of player")
plt.xlabel("Age of players")
plt.ylabel("Number of Players")
plt.show()

# %%
#Winter olympics

Winter_games=df[df['Season']=='Winter'].Sport.unique()
for i in Winter_games:
    print(i)
# Out:
# Speed Skating
# Cross Country Skiing
# Ice Hockey
# Biathlon
# Alpine Skiing
# Luge
# Bobsleigh
# Figure Skating
# Nordic Combined
# Freestyle Skiing
# Ski Jumping
# Curling
# Snowboarding
# Short Track Speed Skating
# Skeleton
# Military Ski Patrol
# Alpinism

# %%
#Summer olympics

Summer_games=df[df['Season']=='Summer'].Sport.unique()
for i in Summer_games:
    print(i)
# Out:
# Basketball
# Judo
# Football
# Tug-Of-War
# Athletics
# Swimming
# Badminton
# Sailing
# Gymnastics
# Art Competitions
# Handball
# Weightlifting
# Wrestling
# Water Polo
# Hockey
# Rowing
# Fencing
# Equestrianism
# Shooting
# Boxing
# Taekwondo
# Cycling
# Diving
# Canoeing
# Tennis
# Modern Pentathlon
# Golf
# Softball
# Archery
# Volleyball
# Synchronized Swimming
# Table Tennis
# Baseball
# Rhythmic Gymnastics
# Rugby Sevens
# Trampolining
# Beach Volleyball
# Triathlon
# Rugby
# Lacrosse
# Polo
# Cricket
# Ice Hockey
# Racquets
# Motorboating
# Croquet
# Figure Skating
# Jeu De Paume
# Roque
# Basque Pelota
# Alpinism
# Aeronautics

# %%
sns.countplot(x='Sex',data=df)
plt.show()

# %%
gender_counts=df['Sex'].value_counts()
plt.figure(figsize=(10,6))
plt.title("Male and female Ratio in olympics")
plt.pie(gender_counts,labels=gender_counts.index,autopct='%1.1f%%',shadow=True)
plt.show()

# %%
# male and female participate olympic in gap 
total_count=df['Sex'].count()
year=np.arange(1896,2017,4).tolist()
for i in year:
    male_count=df['Sex'][df['Sex']=='M'][df['Year']>i].count()
    female_count=df['Sex'][df['Sex']=='F'][df['Year']>i].count()
    male_ratio=int((male_count/total_count)*100)
    female_ratio=int((female_count/total_count)*100)
    gap=male_ratio-female_ratio
    try:
        venue=df.City[df.Year==i].unique()[0]
    except:
        venue='Unknown'
    print(f"male and female ratio{venue}({i}) is : {male_ratio}:{female_ratio} and gap is : {gap}")
# Out:
# male and female ratioAthina(1896) is : 72:27 and gap is : 45
# male and female ratioParis(1900) is : 71:27 and gap is : 44
# male and female ratioSt. Louis(1904) is : 71:27 and gap is : 44
# male and female ratioLondon(1908) is : 69:27 and gap is : 42
# male and female ratioStockholm(1912) is : 67:27 and gap is : 40
# male and female ratioUnknown(1916) is : 67:27 and gap is : 40
# male and female ratioAntwerpen(1920) is : 66:27 and gap is : 39
# male and female ratioParis(1924) is : 64:27 and gap is : 37
# male and female ratioAmsterdam(1928) is : 62:27 and gap is : 35
# male and female ratioLos Angeles(1932) is : 61:26 and gap is : 35
# male and female ratioBerlin(1936) is : 58:26 and gap is : 32
# male and female ratioUnknown(1940) is : 58:26 and gap is : 32
# male and female ratioUnknown(1944) is : 58:26 and gap is : 32
# male and female ratioLondon(1948) is : 56:26 and gap is : 30
# male and female ratioHelsinki(1952) is : 53:25 and gap is : 28
# ...

# %%
plt.figure(figsize=(15,6))
plt.title('male-female participation in olympic')
plt.xlabel('Year')
plt.ylabel('Gap of male female ratio')
plt.yticks(np.arange(0,50,3))
plt.xticks(np.arange(1896,2016,8))
for i in year:
    male_count=df['Sex'][df['Sex']=='M'][df['Year']>i].count()
    female_count=df['Sex'][df['Sex']=='F'][df['Year']>i].count()
    male_ratio=int((male_count/total_count)*100)
    female_ratio=int((female_count/total_count)*100)
    gap=int(male_ratio-female_ratio)
    plt.bar(i,gap)
plt.show()

# %%
# female participate in olympic each summer

female_summer=df[(df['Sex']=='F') & (df['Season']=='Summer')][['Year','Sex']]
female_athletes=female_summer.groupby('Year').count().reset_index()
female_athletes.tail()
# Out:
#     Year   Sex
# 23  2000  5431
# 24  2004  5546
# 25  2008  5816
# 26  2012  5815
# 27  2016  6223

# %%
female_summer=df[(df['Sex']=='F') & (df['Season']=='Summer')]
sns.set(style='darkgrid')
plt.figure(figsize=(16,5))
sns.countplot(x='Year',data=female_summer,palette='Spectral')
plt.ylabel("no of woman participate")
plt.title("woman participate in summer")
# Out:
# Text(0.5, 1.0, 'woman participate in summer')

# %%
Top_contry_medal=df[['Team','Medal']]
Top_contry_medal=Top_contry_medal.groupby('Team').count().sort_values(by='Medal',ascending=False).reset_index()
top=Top_contry_medal.head(10)

# %%
plt.figure(figsize=(15,4))
plt.title("top 10 teams win medals")
sns.barplot(x=top['Team'],y=top['Medal'])
plt.show()

# %%
#gold medal above 60

gold_medal=df[(df['Age']>60) & (df['Medal']=='Gold')][['Name','Age','Team','Sport','Medal']]
gold_medal
# Out:
#                                            Name   Age                Team  \
# 104003                     Isaac Lazarus Israls  63.0         Netherlands
# 105199                          Charles Jacobus  64.0       United States
# 190952  Lida Peyton "Eliza" Pollock (McMillen-)  63.0  Cincinnati Archers
# 226374             Galen Carter "G. C." Spencer  63.0     Potomac Archers
# 233390                        Oscar Gomer Swahn  64.0              Sweden
# 261102                  Robert W. Williams, Jr.  63.0     Potomac Archers
#
#                    Sport Medal
# 104003  Art Competitions  Gold
# 105199             Roque  Gold
# 190952           Archery  Gold
# 226374           Archery  Gold
# 233390          Shooting  Gold
# 261102           Archery  Gold

# %%
gold_medal=gold_medal.groupby('Age').count().sort_values(by='Medal',ascending=False).reset_index()
top=gold_medal.head(10)

# %%
plt.figure(figsize=(15,4))
plt.title("top 10 teams win medals")
sns.barplot(x=top['Age'],y=top['Medal'])
plt.show()
